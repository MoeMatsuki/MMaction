# %%
import cv2
from os import makedirs
from os.path import splitext, dirname, basename, join

def save_frames(video_path: str, frame_dir: str,
                name="img", ext="jpg", max_frame_num=float("inf")):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("cannot open")
        return
    v_name = splitext(basename(video_path))[0]
    if frame_dir[-1:] == "\\" or frame_dir[-1:] == "/":
        frame_dir = dirname(frame_dir)
    frame_dir_ = join(frame_dir, v_name)
    print(f"{frame_dir_} is saved directory")

    makedirs(frame_dir_, exist_ok=True)
    base_path = join(frame_dir_, name)

    idx = 0
    count = 0
    while cap.isOpened():
        idx += 1
        ret, frame = cap.read()
        if ret and count < max_frame_num:
            if cap.get(cv2.CAP_PROP_POS_FRAMES) == 1:  # 0秒のフレームを保存
                cv2.imwrite("{}_{}.{}".format(base_path, "00000", ext),
                            frame)
            elif idx < cap.get(cv2.CAP_PROP_FPS):
                continue
            else:  # 1秒ずつフレームを保存
                second = int(cap.get(cv2.CAP_PROP_POS_FRAMES)/idx)
                filled_second = str(second).zfill(5)
                cv2.imwrite("{}_{}.{}".format(base_path, filled_second, ext),
                            frame)
                idx = 0
            count += 1
        else:
            break

# %%
vid_path = "/content/drive/Shareddrives/ext-東京農工大×KOKUYO/アノテーション/品川オフィス動画/2022年8月｜6F改修前/area2_220823_IMG_0071.MOV"
save_dir = "/content/drive/Shareddrives/ext-東京農工大×KOKUYO/アノテーション/品川オフィス動画/2022年8月｜6F改修前/convert_img"

save_frames(vid_path, save_dir)
# Out:
# /content/drive/Shareddrives/ext-東京農工大×KOKUYO/アノテーション/品川オフィス動画/2022年8月｜6F改修前/convert_img/area2_220823_IMG_0071 is saved directory

# %%
import glob
import re
import os

dir = "/home/moe/MMaction/data/20230703_サンプル/video/"
save_dir = "/home/moe/MMaction/data/20230703_サンプル/convert_img/"

vids = glob.glob(f'{dir}/*.mp4')
for vid in vids:
  save_frames(vid, save_dir)
  print(f"{vid} is done")
# Out:
# /home/moe/MMaction/data/20230703_サンプル/video/Act05_230703_sample_2023-07-03.zip is saved directory
# /home/moe/MMaction/data/20230703_サンプル/video/Act05_230703_sample_2023-07-03.zip.mp4 is done
# /home/moe/MMaction/data/20230703_サンプル/video/Act04_230703_sample_2023-07-03.zip is saved directory
# /home/moe/MMaction/data/20230703_サンプル/video/Act04_230703_sample_2023-07-03.zip.mp4 is done
# /home/moe/MMaction/data/20230703_サンプル/video/Act10_230703_sample_2023-07-03.zip is saved directory
# /home/moe/MMaction/data/20230703_サンプル/video/Act10_230703_sample_2023-07-03.zip.mp4 is done
# /home/moe/MMaction/data/20230703_サンプル/video/Act02_230703_sample_2023-07-03.zip is saved directory
# /home/moe/MMaction/data/20230703_サンプル/video/Act02_230703_sample_2023-07-03.zip.mp4 is done
# /home/moe/MMaction/data/20230703_サンプル/video/Act06_230703_sample_2023-07-03.zip is saved directory
# /home/moe/MMaction/data/20230703_サンプル/video/Act06_230703_sample_2023-07-03.zip.mp4 is done
# /home/moe/MMaction/data/20230703_サンプル/video/Act07_230703_sample_2023-07-03.zip is saved directory
# /home/moe/MMaction/data/20230703_サンプル/video/Act07_230703_sample_2023-07-03.zip.mp4 is done
# /home/moe/MMaction/data/20230703_サンプル/video/Act09_230703_sample_2023-07-03.zip is saved directory
# /home/moe/MMaction/data/20230703_サンプル/video/Act09_230703_sample_2023-07-03.zip.mp4 is done
# /home/moe/MMaction/data/20230703_サンプル/video/Act01_230703_sample_2023-07-03.zip is saved directory
# /home/moe/MMaction/data/20230703_サンプル/video/Act01_230703_sample_2023-07-03.zip.mp4 is done
